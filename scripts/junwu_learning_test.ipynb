# %%
# %run autolign.py
# Out:
# ROS not available. Simulation only.
#
# Starting autolign
# in sim mode (by default)
#
# X1's simulated initial misalignment is: [-0.01849953  0.07441652  0.01334307 -0.00569552] radians
#
# ('i: ', 0, ' E:', 0.0, ' N:', 0.0, ' Psi:', 0.0, ' Ux:', 4.0, ' Uy:', 0.0, ' r:', 0.0)
# e:  0.0  e_LA:  0.0  dPsi:  0
# Steer 0.00 rad and throttle 0.00 N
# Tru mis: [-0.018,0.074,0.013,-0.006]
# Guess:   [0.000,0.000,0.000,0.000]
#
# ('i: ', 1, ' E:', -0.0, ' N:', 0.04, ' Psi:', 0.0, ' Ux:', 4.0, ' Uy:', 0.02, ' r:', 0.01)
# e:  9.6049845789e-05  e_LA:  0.00134074589354  dPsi:  6.22348023874e-05
# Steer -0.00 rad and throttle 4.24 N
# Tru mis: [-0.018,0.074,0.013,-0.006]
# Guess:   [-0.008,-0.008,-0.011,-0.011]
#
# ('i: ', 2, ' E:', -0.0, ' N:', 0.08, ' Psi:', 0.0, ' Ux:', 4.0, ' Uy:', 0.03, ' r:', 0.02)
# e:  0.000360568212737  e_LA:  0.00487023073994  dPsi:  0.00022548312636
# Steer -0.00 rad and throttle 8.10 N
# Tru mis: [-0.018,0.074,0.013,-0.006]
# Guess:   [0.030,0.030,0.040,0.040]
#
# ...

# %%
# %run autolign.py
# Out:
# ROS not available. Simulation only.
#
# Starting autolign
# in sim mode (by default)
#
# X1's simulated initial misalignment is: [-0.08655787  0.05709617 -0.02906146 -0.06726065] radians
#
# i:  0  E: 0  N: 0  Psi: 0  Ux: 4  Uy: 0  r: 0
# e:  0.0  e_LA:  0.0  dPsi:  0
# Steer 0.00 rad and throttle 242.51 N
# Tru mis: [-0.087,0.057,-0.029,-0.067]
# Guess:   [-0.002,0.002,-0.011,-0.012]
#
# i:  1  E: 0.0  N: 0.04  Psi: 0.0  Ux: 4.0  Uy: -0.05  r: 0.02
# e:  -0.00022782902766617955  e_LA:  0.0022448130281516785  dPsi:  0.0001236321027908929
# Steer -0.00 rad and throttle 249.55 N
# Tru mis: [-0.087,0.057,-0.029,-0.067]
# Guess:   [-0.005,-0.014,-0.015,-0.016]
#
# i:  2  E: 0.0  N: 0.08  Psi: 0.0  Ux: 3.99  Uy: -0.08  r: 0.04
# e:  -0.0008378844900844734  e_LA:  0.007745792250151703  dPsi:  0.0004291838370118088
# Steer -0.00 rad and throttle 255.00 N
# Tru mis: [-0.087,0.057,-0.029,-0.067]
# Guess:   [-0.013,0.012,-0.016,-0.010]
#
# ...
